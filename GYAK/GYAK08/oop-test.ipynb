# %%
import numpy as np
from LinearRegressionSkeleton import LinearRegression

# %%
linreg = LinearRegression(epochs=10000)
tests = linreg.fit(linreg.df['petal width (cm)'].values, linreg.df['petal length (cm)'].values)
linreg.predict(linreg.X_test)
# Out:
# 3.7266666666666666
# 3.5235875173348044
# 3.331422140710821
# 3.1495846256145144
# 2.9775205133125042
# 2.814705109121519
# 2.6606418846463527
# 2.514860965787138
# 2.3769177019117675
# 2.2463913118364447
# 2.12288360249122
# 2.00601775636874
# 1.8954371840638435
# 1.790804438409883
# 1.6918001869051866
# 1.598122239300617
# 1.5094846273871028
# 1.4256167341810255
# 1.3462624698557184
# 1.2711794919097246
# 1.2001384671971151
# 1.1329223735727214
# 1.0693258390256575
# 1.00915451628878
# 0.9522244910196757
# 0.8983617217510255
# 0.8474015099049639
# 0.7991879982575293
# 0.7535736963260189
# 0.7104190312339717
# 0.669591922686138
# 0.6309673807591821
# 0.5944271252833363
# 0.5598592256560071
# 0.5271577599905188
# 0.4962224925620536
# 0.4669585685686021
# 0.43927622527741156
# 0.41309051867737845
# 0.3883210648049662
# 0.364891794956004
# 0.34273072403794047
# 0.32176973135715414
# 0.30194435317379154
# 0.2831935863924902
# 0.265459702791124
# 0.24868807322194691
# ...
